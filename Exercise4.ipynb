# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4574-ship-it/python-lab/blob/main/Exercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #list operatiom examples

# %% [markdown]
# #indexing
# #slicing
# #concebtratiob
# #repetion
# #membership
# #iteration

# %%
L1=[1,74,"sujan",'a']
L2=[2,73,"Sudheer",'b']
print(L1[0:3])
# Out:
# [1, 74, 'sujan']

# %%
print(L1[ :3])
# Out:
# [1, 74, 'sujan']

# %%
print(L1[ :2])
print(L2[ :2])
# Out:
# [1, 74]
# [2, 73]

# %%
print(L1[-1])
print(L2[-2])
# Out:
# a
# Sudheer

# %%
L1=[11,22,33,44,55,66,74,"sujan",'a']
L2=[1,2,3,4,5,6,7,8,9,"Sudheer",'b']
print("concentration")
print(L1+L2)
print(L2*3)
print("membership")
print(74 in L1)
print(99 in L2)
print(73 not in L1)
print("indexing")
print(L1[-1])
print(L2[-2])
print("slicing")
print(L1[0 :2])
print(L2[ :2])
print(L1[ :3])
# Out:
# concentration
# [11, 22, 33, 44, 55, 66, 74, 'sujan', 'a', 1, 2, 3, 4, 5, 6, 7, 8, 9, 'Sudheer', 'b']
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 'Sudheer', 'b', 1, 2, 3, 4, 5, 6, 7, 8, 9, 'Sudheer', 'b', 1, 2, 3, 4, 5, 6, 7, 8, 9, 'Sudheer', 'b']
# membership
# True
# False
# True
# indexing
# a
# Sudheer
# slicing
# [11, 22]
# [1, 2]
# [11, 22, 33]

# %%
print(L1)
# Out:
# [11, 22, 33, 44, 55, 66, 74, 'sujan', 'a']
